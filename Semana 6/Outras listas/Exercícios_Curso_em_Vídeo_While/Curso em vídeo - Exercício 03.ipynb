# %%
#3) Crie um programa que peça 2 números para o usuário e então devolva as seguintes opções:
#   [1] Somar números
#   [2] Multiplicar números
#   [3] Maior número
#   [4] Trocar de números
#   [5] Encerrar o programa

# %%
#Variáveis de controle
soma = 0
mult = 0

#Pedir os números para o usuário (Inicio do programa)
num_1 = int(input("Por favor, escolha o primeiro número inteiro: "))
num_2 = int(input("Por favor, escolha o primeiro número inteiro: "))

#Informar o que pode ser feito com esses números e coleta a opção do usuário
print(f"\nVocê escolheu os números {num_1} e {num_2}, o que deseja fazer com eles? \n")
opc = int(input(f"[1] - Somar os números \n[2] - Multiplicar os números \n[3] - Mostre o número maior \n[4] - Trocar os números \n[5] - Encerrar programa: "))

#Verifica se a opção selecionada não é 5
while opc != 5:

#Se a opção for 1:
    if opc == 1:
        soma = num_1 + num_2
        print(f"\nA soma dos dois números é {soma}")
        print("\nE agora, o que deseja fazer?")
        opc = int(input(f"[1] - Somar os números \n[2] - Multiplicar os números \n[3] - Mostre o número maior \n[4] - Trocar os números \n[5] - Encerrar programa: "))
        
#Se a opção for 2:
    elif opc == 2:
        mult = num_1 * num_2
        print(f"\nA multiplicação dos dois números é {mult}")
        print("\nE agora, o que deseja fazer?")
        opc = int(input(f"[1] - Somar os números \n[2] - Multiplicar os números \n[3] - Mostre o número maior \n[4] - Trocar os números \n[5] - Encerrar programa: "))
        
#Se a opção for 3:
    elif opc == 3:
        if num_1 == num_2:
            print(f"\nOs números são iguais!")
        elif num_1 > num_2:
            print(f"\nDentre os números informados, o maior é o {num_1}.")
        else:
            print(f"\nDentre os números informados, o maior é o {num_2}.")
            
        print("\nE agora, o que deseja fazer?")
        opc = int(input(f"[1] - Somar os números \n[2] - Multiplicar os números \n[3] - Mostre o número maior \n[4] - Trocar os números \n[5] - Encerrar programa: "))

#Se a opção for 4
    elif opc == 4:
        num_1 = int(input("Por favor, escolha o primeiro número inteiro: "))
        num_2 = int(input("Por favor, escolha o primeiro número inteiro: "))
        print("\nE agora, o que deseja fazer?")
        opc = int(input(f"[1] - Somar os números \n[2] - Multiplicar os números \n[3] - Mostre o número maior \n[4] - Trocar os números \n[5] - Encerrar programa: "))
        
#Se for outro opção
    else:
        print("\nOpção inválida! Por favor, escolha uma das opções a seguir: ")
        opc = int(input(f"[1] - Somar os números \n[2] - Multiplicar os números \n[3] - Mostre o número maior \n[4] - Trocar os números \n[5] - Encerrar programa: "))

#Se apção for 5    
print("\nPrograma encerrado!")
# Out:
# Por favor, escolha o primeiro número inteiro: 2
# Por favor, escolha o primeiro número inteiro: 5
#
# Você escolheu os números 2 e 5, o que deseja fazer com eles?
#
# [1] - Somar os números
# [2] - Multiplicar os números
# [3] - Mostre o número maior
# [4] - Trocar os números
# [5] - Encerrar programa: 4
# Por favor, escolha o primeiro número inteiro: 2
# Por favor, escolha o primeiro número inteiro: 5
#
# E agora, o que deseja fazer?
# [1] - Somar os números
# [2] - Multiplicar os números
# [3] - Mostre o número maior
# [4] - Trocar os números
# [5] - Encerrar programa: 3
#
# Dentre os números informados, o maior é o 5.
#
# E agora, o que deseja fazer?
# [1] - Somar os números
# [2] - Multiplicar os números
# [3] - Mostre o número maior
# [4] - Trocar os números
# [5] - Encerrar programa: 1
#
# A soma dos dois números é 7
#
# E agora, o que deseja fazer?
# [1] - Somar os números
# [2] - Multiplicar os números
# [3] - Mostre o número maior
# [4] - Trocar os números
# ...
